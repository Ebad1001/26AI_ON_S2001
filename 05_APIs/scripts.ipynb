# %% [markdown]
# **API** = `Application Programming Interface`
#
# An API allows different software applications to talk to each other. It acts as a middleman, taking a request from one program, delivering it to another, and bringing the response back.

# %% [markdown]
# - Lets look at some examples to understand the use of APIs

# %%
import requests
import json

country_name = "india"
response = requests.get(f"https://restcountries.com/v5/name/{country_name}")
json_data = json.loads(response.text)

with open("output.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %%
import requests
import json

latitude, longitude, weather = 28.5424263, 77.1829994, True
response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current_weather={weather}")
json_data = json.loads(response.text)

with open("output.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %%
import requests
import json

pokemon_name = "pikachu"
response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{pokemon_name}")
json_data = json.loads(response.text)

with open("output.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# - Some more examples of APIs that we can use to make useful apps

# %%
import requests
import json


convert_from = "INR"
response = requests.get(f"https://api.exchangerate-api.com/v4/latest/{convert_from}")
json_data = json.loads(response.text)

with open("output.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %%
import requests
import json

amount = 100
convert_from = "INR"
convert_to = "JPY"

url = f"https://api.exchangerate-api.com/v4/latest/{convert_from}"
response = requests.get(url)
json_data = json.loads(response.text)
    
multiplier = json_data["rates"][convert_to]
answer = amount * multiplier

print(f"{amount} {convert_from} is equal to {answer} {convert_to}")
# Out:
# 100 INR is equal to 168.0 JPY

# %%
import requests
import json

word = "SCHEDULE"
response = requests.get(f"https://api.dictionaryapi.dev/api/v2/entries/en/{word}")
json_data = response.json()

with open("output.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

print("Word:", json_data[0]["word"])
print("Meaning:", json_data[0]["meanings"][0]["definitions"][0]["definition"])
# Out:
# Word: schedule
# Meaning: A slip of paper; a short note.

# %%
import requests
import json

usernames = [
    "Mishikaka", "Hayaan67", "icebot745",
    "shells1082-blip", "samarthyallapragada-blip",
    "HopingForAChange", "yuviacc", "revs2211-coder"
]

for name in usernames:
    url = f"https://api.github.com/users/{name}"

    response = requests.get(url)
    json_data = response.json()

    # with open("output.json", "w", encoding="utf-8") as f:
    #     json.dump(json_data, f, ensure_ascii=False, indent=4)

    if response.status_code == 200:
        data = response.json()
        
        print("Username:", data["login"], "/", data["name"])
        print("Public Repos:", data["public_repos"])
        print()
        # print("Followers:", data["followers"])
        # print("Following:", data["following"])
    else:
        print("Error:", response.status_code)
# Out:
# Username: Mishikaka / KAKA
# Public Repos: 1
#
# Username: Hayaan67 / hayaansinghal
# Public Repos: 1
#
# Username: icebot745 / None
# Public Repos: 3
#
# Username: shells1082-blip / Krisha
# Public Repos: 3
#
# Username: samarthyallapragada-blip / None
# Public Repos: 3
#
# Username: HopingForAChange / ReyanshK1701
# Public Repos: 4
#
# Username: yuviacc / None
# Public Repos: 3
#
# Username: revs2211-coder / None
# Public Repos: 1
